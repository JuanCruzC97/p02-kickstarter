# %% [markdown]
# # Kickstarter
#
# Este notebook permite importar rápidamente los datos del proyecto Kickstarter a una sesión de Google Colab para trabajar con los mismos.

# %%
# !git clone https://github.com/JuanCruzC97/p02-kickstarter.git &> /dev/null

# %%
cd p02-kickstarter

# %% [markdown]
# ## Importamos módulos

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Importamos el dataset
#
# Podemos importar tanto el set de datos de entrenamiento `train`. Los mismos tienen disponibles tanto las variables explicativas como las variables respuesta. El formato del archivo es un `tsv`, los valores están separados por tabulaciones.

# %%
train = pd.read_csv("data/train.tsv", sep="\t", index_col=0)
train
# Out:
#      fecha_inicial fecha_final            pais                  ciudad  \
# 0       2019-04-01  2019-05-01           Spain                  España
# 1       2019-03-29  2019-04-26   United States                  Newnan
# 2       2019-03-12  2019-04-19          France                  France
# 3       2019-04-12  2019-04-21  United Kingdom  Brighton and Hove City
# 4       2019-04-01  2019-05-01   United States              Blacksburg
# ...            ...         ...             ...                     ...
# 6061    2018-12-18  2019-02-16   United States               Cambridge
# 6062    2019-02-24  2019-03-26   United States                 Norfolk
# 6063    2019-02-12  2019-02-27   United States                Portland
# 6064    2019-02-23  2019-04-24   United States            Connersville
# 6065    2019-03-12  2019-04-11       Singapore               Singapore
#
#       descripcion_largo  descripcion_full_largo  titulo_largo  \
# ...
